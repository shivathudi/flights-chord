# %%
import pandas as pd
import numpy as np

# %%
flights = pd.read_csv('flights.csv')
meta = pd.read_csv('airports_meta.csv', header=None, names = ["row_num", "airport_full_name", "airport_city", "country", "airport_code", 
                                                              "airport_random_id", "lat", "lon", "r_1", "r_2", "r_3", "timezone", "r_4", "r_5" ])

# %%
flights.head()
# Out:
#   CARRIER_CODE ORIGIN ORIGIN_STATE_ABR DEST DEST_STATE_ABR  CRS_DEP_TIME  \
# 0           AA    CLT               NC  SYR             NY             5
# 1           DL    LAS               NV  ATL             GA             5
# 2           AA    SEA               WA  CLT             NC             5
# 3           AA    SEA               WA  ORD             IL            10
# 4           AA    CLT               NC  JAX             FL            10
#
#    DEP_TIME  DEP_DELAY  CRS_ARR_TIME  ARR_TIME    ...      CARRIER_DELAY  \
# 0    2358.0       -7.0           146     131.0    ...                0.0
# 1       4.0       -1.0           645     637.0    ...                0.0
# 2       6.0        1.0           804     741.0    ...                0.0
# 3      11.0        1.0           605     547.0    ...                0.0
# 4       6.0       -4.0           125     123.0    ...                0.0
#
#    WEATHER_DELAY NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  CARRIER_NAME  \
# 0            0.0       0.0             0.0                  0.0      American
# 1            0.0       0.0             0.0                  0.0         Delta
# 2            0.0       0.0             0.0                  0.0      American
# 3            0.0       0.0             0.0                  0.0      American
# 4            0.0       0.0             0.0                  0.0      American
#
#    OriginLat   OriginLon    DestLat    DestLon
# 0  35.214001  -80.943100  43.111198 -76.106300
# 1  36.080101 -115.152000  33.636700 -84.428101
# 2  47.449001 -122.308998  35.214001 -80.943100
# 3  47.449001 -122.308998  41.978600 -87.904800
# 4  35.214001  -80.943100  30.494101 -81.687897
#
# [5 rows x 25 columns]

# %%
flights.shape
# Out:
# (9778, 25)

# %%
flights.columns
# Out:
# Index([u'CARRIER_CODE', u'ORIGIN', u'ORIGIN_STATE_ABR', u'DEST',
#        u'DEST_STATE_ABR', u'CRS_DEP_TIME', u'DEP_TIME', u'DEP_DELAY',
#        u'CRS_ARR_TIME', u'ARR_TIME', u'ARR_DELAY', u'CANCELLED',
#        u'CANCELLATION_CODE', u'ACTUAL_ELAPSED_TIME', u'DISTANCE',
#        u'CARRIER_DELAY', u'WEATHER_DELAY', u'NAS_DELAY', u'SECURITY_DELAY',
#        u'LATE_AIRCRAFT_DELAY', u'CARRIER_NAME', u'OriginLat', u'OriginLon',
#        u'DestLat', u'DestLon'],
#       dtype='object')

# %%
outbound_flights = pd.DataFrame(flights.groupby(['ORIGIN'], as_index=False).size().rename('outbound'))
inbound_flights = pd.DataFrame(flights.groupby(['DEST'], as_index=False).size().rename('inbound'))

# %%
merged_df = outbound_flights.merge(inbound_flights, left_index=True, right_index=True)

# %%
merged_df['total'] = merged_df['inbound'] + merged_df['outbound']

# %%
merged_df.head()
# Out:
#      outbound  inbound  total
# ABQ        31       30     61
# ACY        11       11     22
# ADQ         1        1      2
# ALB        18       19     37
# AMA         4        4      8

# %%
top_busiest = list(merged_df.sort_values('total', ascending=False)[:30].index)

# %%
top_busiest
# Out:
# ['ATL',
#  'LAX',
#  'DEN',
#  'PHX',
#  'MCO',
#  'LAS',
#  'DFW',
#  'ORD',
#  'SFO',
#  'SEA',
#  'JFK',
#  'FLL',
#  'CLT',
#  'BOS',
#  'MIA',
#  'BWI',
#  'EWR',
#  'MDW',
#  'IAH',
#  'MSP',
#  'TPA',
#  'SAN',
#  'LGA',
#  'DTW',
#  'PHL',
#  'SLC',
#  'DAL',
#  'HNL',
#  'DCA',
#  'PDX']

# %%
len(top_busiest)
# Out:
# 30

# %%
# Convert smaller airports to OTHER category
flights_top = flights.copy().merge(meta, left_on="ORIGIN", right_on = "airport_code")


flights_top['ORIGIN'] = flights_top['ORIGIN'].apply(lambda x: x if x in top_busiest else 'OTHER')
flights_top['DEST'] = flights_top['DEST'].apply(lambda x: x if x in top_busiest else 'OTHER')

# %%
flights_top
# Out:
#      CARRIER_CODE ORIGIN ORIGIN_STATE_ABR   DEST DEST_STATE_ABR  CRS_DEP_TIME  \
# 0              AA    CLT               NC  OTHER             NY             5
# 1              AA    CLT               NC  OTHER             FL            10
# 2              AA    CLT               NC    DCA             VA            15
# 3              AA    CLT               NC    FLL             FL            15
# 4              AA    CLT               NC  OTHER             VA            15
# 5              AA    CLT               NC  OTHER             MO            15
# 6              AA    CLT               NC    BWI             MD            15
# 7              AA    CLT               NC  OTHER             VA            20
# 8              AA    CLT               NC    PHL             PA            20
# 9              AA    CLT               NC  OTHER             PA            20
# 10             AA    CLT               NC    MCO             FL            20
# 11             AA    CLT               NC    EWR             NJ            25
# 12             AA    CLT               NC  OTHER             CT            25
# 13             AA    CLT               NC    TPA             FL            25
# 14             AA    CLT               NC  OTHER             FL            25
# 15             AA    CLT               NC    BOS             MA            30
# 16             AA    CLT               NC  OTHER             NC            30
# 17             AA    CLT               NC    ATL             GA            34
# 18             AA    CLT               NC  OTHER             LA            36
# 19             DL    CLT               NC    DTW             MI           559
# 20             AA    CLT               NC    PHL             PA           630
# 21             WN    CLT               NC    BWI             MD           640
# 22             UA    CLT               NC    ORD             IL           644
# 23             F9    CLT               NC    DEN             CO           645
# 24             AA    CLT               NC    MIA             FL           700
# 25             DL    CLT               NC    ATL             GA           700
# 26             DL    CLT               NC    SLC             UT           720
# 27             AA    CLT               NC    SFO             CA           730
# 28             AA    CLT               NC    DFW             TX           730
# 29             AA    CLT               NC    SEA             WA           730
# ...           ...    ...              ...    ...            ...           ...
# 9748           UA  OTHER               CO    EWR             NJ          1335
# 9749           UA  OTHER               CO    IAH             TX          1445
# 9750           AA  OTHER               CO    DFW             TX          1611
# 9751           AS  OTHER               AK  OTHER             AK          1159
# 9752           AS  OTHER               AK  OTHER             AK          1830
# 9753           UA  OTHER               CO    EWR             NJ          1201
# 9754           DL  OTHER               CO    ATL             GA          1250
# 9755           UA  OTHER               CO  OTHER             VA          1305
# 9756           AA  OTHER               CO    DFW             TX          1315
# 9757           UA  OTHER               CO    IAH             TX          1428
# 9758           AA  OTHER               CO    DFW             TX          1600
# 9759           AS  OTHER               AK  OTHER             AK          1210
# 9760           AS  OTHER               AK  OTHER             AK          1855
# 9761           AS  OTHER               AK  OTHER             AK          2011
# 9762           AS  OTHER               AK  OTHER             AK          1213
# 9763           AS  OTHER               AK  OTHER             AK          1829
# 9764           AS  OTHER               AK  OTHER             AK          1225
# 9765           AS  OTHER               AK  OTHER             AK          2029
# 9766           AS  OTHER               AK  OTHER             AK          1228
# 9767           AS  OTHER               AK  OTHER             AK          1520
# 9768           AA  OTHER               CO    DFW             TX          1233
# 9769           UA  OTHER               CO    IAH             TX          1415
# 9770           B6  OTHER               MA    FLL             FL          1255
# 9771           B6  OTHER               MA    MCO             FL          1609
# 9772           AS  OTHER               AK  OTHER             AK          1317
# 9773           AS  OTHER               AK  OTHER             AK          1338
# 9774           AS  OTHER               AK  OTHER             AK          1657
# 9775           AS  OTHER               AK  OTHER             AK          1710
# 9776           B6  OTHER               NY    MCO             FL          1710
# 9777           B6  OTHER               NY    FLL             FL          1850
#
#       DEP_TIME  DEP_DELAY  CRS_ARR_TIME  ARR_TIME     ...       airport_code  \
# 0       2358.0       -7.0           146     131.0     ...                CLT
# 1          6.0       -4.0           125     123.0     ...                CLT
# 2          8.0       -7.0           133     125.0     ...                CLT
# 3          9.0       -6.0           214     200.0     ...                CLT
# 4          6.0       -9.0           116     107.0     ...                CLT
# 5          8.0       -7.0           143     141.0     ...                CLT
# 6          3.0      -12.0           134     113.0     ...                CLT
# 7         10.0      -10.0           120     108.0     ...                CLT
# 8         13.0       -7.0           152     134.0     ...                CLT
# 9          9.0      -11.0           136     124.0     ...                CLT
# 10        16.0       -4.0           154     156.0     ...                CLT
# 11        17.0       -8.0           212     157.0     ...                CLT
# 12        16.0       -9.0           211     202.0     ...                CLT
# 13        32.0        7.0           159     201.0     ...                CLT
# 14        22.0       -3.0           211     213.0     ...                CLT
# 15        21.0       -9.0           229     219.0     ...                CLT
# 16        22.0       -8.0           116     104.0     ...                CLT
# 17        28.0       -6.0           144     126.0     ...                CLT
# 18        30.0       -6.0           134     121.0     ...                CLT
# 19       558.0       -1.0           747     752.0     ...                CLT
# 20       629.0       -1.0           805     809.0     ...                CLT
# 21       632.0       -8.0           800     813.0     ...                CLT
# 22       659.0       15.0           750     751.0     ...                CLT
# 23       701.0       16.0           839     843.0     ...                CLT
# 24       700.0        0.0           859     850.0     ...                CLT
# 25       658.0       -2.0           820     813.0     ...                CLT
# 26       719.0       -1.0          1006     957.0     ...                CLT
# 27       728.0       -2.0          1012    1002.0     ...                CLT
# 28       753.0       23.0           928    1000.0     ...                CLT
# 29       727.0       -3.0          1017    1004.0     ...                CLT
# ...        ...        ...           ...       ...     ...                ...
# 9748    1355.0       20.0          1948    1930.0     ...                MTJ
# 9749    1437.0       -8.0          1819    1824.0     ...                MTJ
# 9750    1556.0      -15.0          1925    1848.0     ...                MTJ
# 9751    1140.0      -19.0          1253    1228.0     ...                YAK
# 9752    1751.0      -39.0          1919    1854.0     ...                YAK
# 9753    1218.0       17.0          1803    1805.0     ...                HDN
# 9754    1304.0       14.0          1804    1754.0     ...                HDN
# 9755    1251.0      -14.0          1846    1802.0     ...                HDN
# 9756    1304.0      -11.0          1637    1609.0     ...                HDN
# 9757    1418.0      -10.0          1814    1750.0     ...                HDN
# 9758     854.0     1014.0          1920    1322.0     ...                HDN
# 9759    1150.0      -20.0          1330    1316.0     ...                BRW
# 9760    1842.0      -13.0          2048    2031.0     ...                BRW
# 9761    1942.0      -29.0          2204    2134.0     ...                BRW
# 9762    1156.0      -17.0          1300    1239.0     ...                SIT
# 9763    1807.0      -22.0          1909    1846.0     ...                SIT
# 9764    1204.0      -21.0          1352    1332.0     ...                OME
# 9765    2018.0      -11.0          2154    2143.0     ...                OME
# 9766    1206.0      -22.0          1307    1238.0     ...                PSG
# 9767    1502.0      -18.0          1545    1520.0     ...                PSG
# 9768    1222.0      -11.0          1538    1520.0     ...                GUC
# 9769    1415.0        0.0          1752    1733.0     ...                GUC
# 9770    1300.0        5.0          1616    1612.0     ...                ORH
# 9771    1555.0      -14.0          1918    1844.0     ...                ORH
# 9772    1323.0        6.0          1425    1424.0     ...                BET
# 9773    1310.0      -28.0          1425    1349.0     ...                CDV
# 9774    1629.0      -28.0          1745    1728.0     ...                CDV
# 9775       NaN        NaN          1759       NaN     ...                ADQ
# 9776    1712.0        2.0          2009    1954.0     ...                SWF
# 9777    1839.0      -11.0          2208    2122.0     ...                SWF
#
#       airport_random_id        lat         lon   r_1  r_2  r_3  \
# 0                  KCLT  35.214001  -80.943100   748   -5    A
# 1                  KCLT  35.214001  -80.943100   748   -5    A
# 2                  KCLT  35.214001  -80.943100   748   -5    A
# 3                  KCLT  35.214001  -80.943100   748   -5    A
# 4                  KCLT  35.214001  -80.943100   748   -5    A
# 5                  KCLT  35.214001  -80.943100   748   -5    A
# 6                  KCLT  35.214001  -80.943100   748   -5    A
# 7                  KCLT  35.214001  -80.943100   748   -5    A
# 8                  KCLT  35.214001  -80.943100   748   -5    A
# 9                  KCLT  35.214001  -80.943100   748   -5    A
# 10                 KCLT  35.214001  -80.943100   748   -5    A
# 11                 KCLT  35.214001  -80.943100   748   -5    A
# 12                 KCLT  35.214001  -80.943100   748   -5    A
# 13                 KCLT  35.214001  -80.943100   748   -5    A
# 14                 KCLT  35.214001  -80.943100   748   -5    A
# 15                 KCLT  35.214001  -80.943100   748   -5    A
# 16                 KCLT  35.214001  -80.943100   748   -5    A
# 17                 KCLT  35.214001  -80.943100   748   -5    A
# 18                 KCLT  35.214001  -80.943100   748   -5    A
# 19                 KCLT  35.214001  -80.943100   748   -5    A
# 20                 KCLT  35.214001  -80.943100   748   -5    A
# 21                 KCLT  35.214001  -80.943100   748   -5    A
# 22                 KCLT  35.214001  -80.943100   748   -5    A
# 23                 KCLT  35.214001  -80.943100   748   -5    A
# 24                 KCLT  35.214001  -80.943100   748   -5    A
# 25                 KCLT  35.214001  -80.943100   748   -5    A
# 26                 KCLT  35.214001  -80.943100   748   -5    A
# 27                 KCLT  35.214001  -80.943100   748   -5    A
# 28                 KCLT  35.214001  -80.943100   748   -5    A
# 29                 KCLT  35.214001  -80.943100   748   -5    A
# ...                 ...        ...         ...   ...  ...  ...
# 9748               KMTJ  38.509800 -107.893997  5759   -7    A
# 9749               KMTJ  38.509800 -107.893997  5759   -7    A
# 9750               KMTJ  38.509800 -107.893997  5759   -7    A
# 9751               PAYA  59.503300 -139.660004    33   -9    A
# 9752               PAYA  59.503300 -139.660004    33   -9    A
# 9753               KHDN  40.481201 -107.218002  6606   -7    A
# 9754               KHDN  40.481201 -107.218002  6606   -7    A
# 9755               KHDN  40.481201 -107.218002  6606   -7    A
# 9756               KHDN  40.481201 -107.218002  6606   -7    A
# 9757               KHDN  40.481201 -107.218002  6606   -7    A
# 9758               KHDN  40.481201 -107.218002  6606   -7    A
# 9759               PABR  71.285402 -156.766008    44   -9    A
# 9760               PABR  71.285402 -156.766008    44   -9    A
# 9761               PABR  71.285402 -156.766008    44   -9    A
# 9762               PASI  57.047100 -135.362000    21   -9    A
# 9763               PASI  57.047100 -135.362000    21   -9    A
# 9764               PAOM  64.512199 -165.445007    37   -9    A
# 9765               PAOM  64.512199 -165.445007    37   -9    A
# 9766               PAPG  56.801701 -132.945007   111   -9    A
# 9767               PAPG  56.801701 -132.945007   111   -9    A
# 9768               KGUC  38.533901 -106.932999  7680   -7    A
# 9769               KGUC  38.533901 -106.932999  7680   -7    A
# 9770               KORH  42.267300  -71.875702  1009   -5    A
# 9771               KORH  42.267300  -71.875702  1009   -5    A
# 9772               PABE  60.779800 -161.837997   126   -9    A
# 9773               PACV  60.491798 -145.477997    54   -9    A
# 9774               PACV  60.491798 -145.477997    54   -9    A
# 9775               PADQ  57.750000 -152.494003    78   -9    A
# 9776               KSWF  41.504101  -74.104797   491   -5    A
# 9777               KSWF  41.504101  -74.104797   491   -5    A
#
#                timezone      r_4          r_5
# 0      America/New_York  airport  OurAirports
# 1      America/New_York  airport  OurAirports
# 2      America/New_York  airport  OurAirports
# 3      America/New_York  airport  OurAirports
# 4      America/New_York  airport  OurAirports
# 5      America/New_York  airport  OurAirports
# 6      America/New_York  airport  OurAirports
# 7      America/New_York  airport  OurAirports
# 8      America/New_York  airport  OurAirports
# 9      America/New_York  airport  OurAirports
# 10     America/New_York  airport  OurAirports
# 11     America/New_York  airport  OurAirports
# 12     America/New_York  airport  OurAirports
# 13     America/New_York  airport  OurAirports
# 14     America/New_York  airport  OurAirports
# 15     America/New_York  airport  OurAirports
# 16     America/New_York  airport  OurAirports
# 17     America/New_York  airport  OurAirports
# 18     America/New_York  airport  OurAirports
# 19     America/New_York  airport  OurAirports
# 20     America/New_York  airport  OurAirports
# 21     America/New_York  airport  OurAirports
# 22     America/New_York  airport  OurAirports
# 23     America/New_York  airport  OurAirports
# 24     America/New_York  airport  OurAirports
# 25     America/New_York  airport  OurAirports
# 26     America/New_York  airport  OurAirports
# 27     America/New_York  airport  OurAirports
# 28     America/New_York  airport  OurAirports
# 29     America/New_York  airport  OurAirports
# ...                 ...      ...          ...
# 9748     America/Denver  airport  OurAirports
# 9749     America/Denver  airport  OurAirports
# 9750     America/Denver  airport  OurAirports
# 9751  America/Anchorage  airport  OurAirports
# 9752  America/Anchorage  airport  OurAirports
# 9753     America/Denver  airport  OurAirports
# 9754     America/Denver  airport  OurAirports
# 9755     America/Denver  airport  OurAirports
# 9756     America/Denver  airport  OurAirports
# 9757     America/Denver  airport  OurAirports
# 9758     America/Denver  airport  OurAirports
# 9759  America/Anchorage  airport  OurAirports
# 9760  America/Anchorage  airport  OurAirports
# 9761  America/Anchorage  airport  OurAirports
# 9762  America/Anchorage  airport  OurAirports
# 9763  America/Anchorage  airport  OurAirports
# 9764  America/Anchorage  airport  OurAirports
# 9765  America/Anchorage  airport  OurAirports
# 9766  America/Anchorage  airport  OurAirports
# 9767  America/Anchorage  airport  OurAirports
# 9768     America/Denver  airport  OurAirports
# 9769     America/Denver  airport  OurAirports
# 9770   America/New_York  airport  OurAirports
# 9771   America/New_York  airport  OurAirports
# 9772  America/Anchorage  airport  OurAirports
# 9773  America/Anchorage  airport  OurAirports
# 9774  America/Anchorage  airport  OurAirports
# 9775  America/Anchorage  airport  OurAirports
# 9776   America/New_York  airport  OurAirports
# 9777   America/New_York  airport  OurAirports
#
# [9778 rows x 39 columns]

# %%
# flights_top = flights[(flights.ORIGIN.isin(top_busiest)) & (flights.DEST.isin(top_busiest))]

# %%
flights_top.shape
# Out:
# (9778, 39)

# %%
# TOO MANY STATES TO COLOR BY
len(flights_top['ORIGIN_STATE_ABR'].unique())
# Out:
# 51

# %%
#  fl_top_merged = flights_top.merge(meta, left_on="ORIGIN", right_on = "airport_code")

# %%
# fl_top_merged.shape

# %%
# fl_top_merged.columns

# %%
fl_top_merged = flights_top.copy()

# %%
fl_top_merged['ORIGIN'].unique()
# Out:
# array(['CLT', 'LAS', 'SEA', 'DEN', 'SLC', 'PDX', 'SFO', 'MSP', 'LAX',
#        'PHX', 'OTHER', 'HNL', 'EWR', 'BOS', 'PHL', 'ORD', 'FLL', 'DFW',
#        'JFK', 'IAH', 'TPA', 'BWI', 'MCO', 'DTW', 'DCA', 'LGA', 'MIA',
#        'ATL', 'DAL', 'MDW', 'SAN'], dtype=object)

# %%
# fl_top_merged['timezone'] = 
fl_top_merged.apply(lambda row: row['timezone'] if row['ORIGIN'] in top_busiest else 'OTHER_TIMEZONE', axis = 1).unique()
# Out:
# array(['America/New_York', 'America/Los_Angeles', 'America/Denver',
#        'America/Chicago', 'America/Phoenix', 'OTHER_TIMEZONE',
#        'Pacific/Honolulu'], dtype=object)

# %%
fl_top_merged['timezone'] = fl_top_merged.apply(lambda row: row['timezone'] if row['ORIGIN'] in top_busiest else 'OTHER_TIMEZONE', axis = 1)

# %%
fl_top_merged['timezone'].unique()
# Out:
# array(['America/New_York', 'America/Los_Angeles', 'America/Denver',
#        'America/Chicago', 'America/Phoenix', 'OTHER_TIMEZONE',
#        'Pacific/Honolulu'], dtype=object)

# %%
gb = fl_top_merged.groupby(['ORIGIN', 'DEST', 'timezone' ], as_index=False).size()
gb.name = 'size'
gb = gb.reset_index()

# %%
# I guess some airports don't have any flights to other airports (30*29) = 870, but we have 742.
gb.shape
# Out:
# (803, 4)

# %%
gb.head()
# Out:
#   ORIGIN DEST          timezone  size
# 0    ATL  BOS  America/New_York    10
# 1    ATL  BWI  America/New_York    11
# 2    ATL  CLT  America/New_York    10
# 3    ATL  DAL  America/New_York     3
# 4    ATL  DCA  America/New_York    10

# %%
gb['ORIGIN'].unique()
# Out:
# array(['ATL', 'BOS', 'BWI', 'CLT', 'DAL', 'DCA', 'DEN', 'DFW', 'DTW',
#        'EWR', 'FLL', 'HNL', 'IAH', 'JFK', 'LAS', 'LAX', 'LGA', 'MCO',
#        'MDW', 'MIA', 'MSP', 'ORD', 'OTHER', 'PDX', 'PHL', 'PHX', 'SAN',
#        'SEA', 'SFO', 'SLC', 'TPA'], dtype=object)

# %%
set(gb['ORIGIN'].unique()) == set(top_busiest)
# Out:
# False

# %%
# Phoenix and Los Angeles follow the same time, so I make it the same color and group

tz_colgrp_map = {
    'America/Puerto_Rico' : ("#FF7F00", 1),
    'America/New_York' : ("#FF7F00", 1),
    'America/Chicago' : ("#377EB8", 2),
    'America/Denver' : ("#F781BF", 3),
    'America/Los_Angeles' : ("#A0522D", 4),
    'America/Phoenix' : ("#A0522D", 4),
    'Pacific/Honolulu' : ("#984EA3", 5),
    'OTHER_TIMEZONE' : ("#4DAF4A", 6) 
}


def get_color(timezone):    
    return tz_colgrp_map[timezone][0]

def get_group(timezone):    
    return tz_colgrp_map[timezone][1]

# %%
gb['color'] = gb['timezone'].apply(lambda x: get_color(x))

# %%
gb['group'] = gb['timezone'].apply(lambda x: get_group(x))

# %%
gb.sort_values(['group', 'ORIGIN'], inplace=True)

# %%
# len(gb['airport_full_name'].unique())

# %%
gb['ORIGIN'].unique()
# Out:
# array(['ATL', 'BOS', 'BWI', 'CLT', 'DCA', 'DTW', 'EWR', 'FLL', 'JFK',
#        'LGA', 'MCO', 'MIA', 'PHL', 'TPA', 'DAL', 'DFW', 'IAH', 'MDW',
#        'MSP', 'ORD', 'DEN', 'SLC', 'LAS', 'LAX', 'PDX', 'PHX', 'SAN',
#        'SEA', 'SFO', 'HNL', 'OTHER'], dtype=object)

# %%
gb.columns
# Out:
# Index([u'ORIGIN', u'DEST', u'timezone', u'size', u'color', u'group'], dtype='object')

# %%
gb.to_csv('flights-chord.csv', index=False)

# %%
flights_airports = gb.groupby(['ORIGIN', 'group', 'color'], as_index=False).sum().sort_values(['group', 'size'], ascending = [True, False]).reset_index()

# %%
flights_airports.sort_values(['group', 'size'], ascending = [True, False], inplace=True)

# %%
flights_airports['name'] = flights_airports['ORIGIN']

# %%
flights_airports.to_csv('flights-airports.csv', index=False)

# %%
total_flights = np.sum(gb['size'])

# %%
airports = list(flights_airports.name)

# %%
airports
# Out:
# ['ATL',
#  'MCO',
#  'JFK',
#  'FLL',
#  'CLT',
#  'BOS',
#  'BWI',
#  'MIA',
#  'EWR',
#  'LGA',
#  'TPA',
#  'DTW',
#  'PHL',
#  'DCA',
#  'DFW',
#  'ORD',
#  'MDW',
#  'MSP',
#  'IAH',
#  'DAL',
#  'DEN',
#  'SLC',
#  'LAX',
#  'PHX',
#  'LAS',
#  'SFO',
#  'SEA',
#  'SAN',
#  'PDX',
#  'HNL',
#  'OTHER']

# %%
adj_matrix = []
for airport_orig in airports:
    row = []
    for airport_dest in airports:
        record = gb.loc[(gb.ORIGIN == airport_orig) & (gb.DEST == airport_dest), 'size']
        if len(record) != 0:
            row.append(record.values[0]*1.0/total_flights)
        else:
            row.append(0)
    adj_matrix.append(row)

